# %%
import os
import numpy as np
import pandas as pd
import tifffile as tiff  # Use tifffile instead of Pillow for reading TIFF images

# Define the class values for all crops (normal and irrigated variants)
crop_classes = {
    "Potato": [10, 110],
    "Orchard (dense)": [13, 113],
    "Grapes": [15, 115],
    "Wheat": [108],
    "Maize": [109],
    "Potatoes": [110],
    "Grapes (Irrigated)": [115],
    "Rice": [120],
    "Cotton": [124],
    "Clover": [125],
    "Onions": [126],
    "Carrots": [127],
    "Eggplants": [128],
    "Flax": [129],
    "Sugar beet": [131]
}

# Directories containing the AETI and Land Classification files
aeti_dir = r'D:\Thesis Work\FAO_WAPOR_Data\waporact_test\L3\02_download\L3_AETI_D'
land_class_dir = r'D:\Thesis Work\FAO_WAPOR_Data\waporact_test\L3\02_download\L3_LCC_D'

# Initialize a list to store the results
results = []

# List files in both directories
aeti_files = os.listdir(aeti_dir)
land_class_files = os.listdir(land_class_dir)

# Extract the number after AETI and LCC in filenames for pairing
def extract_number(filename, prefix):
    start = filename.find(prefix) + len(prefix)
    end = filename.find('.tif', start)
    return filename[start:end]

# Create a dictionary for land class files with extracted numbers as keys
land_class_dict = {extract_number(f, 'LCC_'): f for f in land_class_files if f.endswith('.tif')}

# Function to process each pair of AETI and Land Classification files
def process_files(aeti_file, land_class_file):
    # Load the images using tifffile
    aeti_data = tiff.imread(aeti_file)
    land_class_data = tiff.imread(land_class_file)
    
    # Dictionary to store the average AETI for each crop
    crop_aeti_values = {}
    
    # Iterate over all crops
    for crop_name, class_values in crop_classes.items():
        # Identify pixels corresponding to the crop in the land classification image
        crop_pixels = np.isin(land_class_data, class_values)
        
        # Extract the corresponding AETI values for the crop
        crop_aeti = aeti_data[crop_pixels]
        
        # Filter out no-data values (assuming -9999.0 is a no-data value)
        valid_crop_aeti = crop_aeti[crop_aeti != -9999.0]
        
        # Sum and then average the AETI values for the crop
        if valid_crop_aeti.size > 0:
            avg_aeti = np.mean(valid_crop_aeti)
        else:
            avg_aeti = np.nan
        
        crop_aeti_values[crop_name] = avg_aeti
    
    return crop_aeti_values

# Iterate through the AETI files and find the corresponding land class files
for aeti_filename in aeti_files:
    if aeti_filename.endswith('.tif'):
        # Extract the number from the AETI filename
        number = extract_number(aeti_filename, 'AETI_')
        
        # Find the corresponding land class filename using the extracted number
        land_class_filename = land_class_dict.get(number)
        
        if land_class_filename:
            # Construct the full file paths
            aeti_file_path = os.path.join(aeti_dir, aeti_filename)
            land_class_file_path = os.path.join(land_class_dir, land_class_filename)
            
            # Process the files and calculate the combined average AETI for each crop
            crop_aeti_values = process_files(aeti_file_path, land_class_file_path)
            
            # Assuming that date extraction should be updated to match your file naming convention
            date = number
            
            # Append the results to the list with the date
            for crop_name, avg_aeti in crop_aeti_values.items():
                results.append({
                    'Date': date,
                    'Crop': crop_name,
                    'Average AETI': avg_aeti
                })
            print(f"Processed {aeti_filename} and {land_class_filename}")
        else:
            print(f"Matching land class file not found for {aeti_filename}")

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results)

# Save the results to a CSV file
results_df.to_csv('average_aeti_all_crops.csv', index=False)
print("Results saved to average_aeti_all_crops.csv")
# Out:
# Processed L3_AETI_0901.tif and L3_LCC_0901.tif
# Processed L3_AETI_0902.tif and L3_LCC_0902.tif
# Processed L3_AETI_0903.tif and L3_LCC_0903.tif
# Processed L3_AETI_0904.tif and L3_LCC_0904.tif
# Processed L3_AETI_0905.tif and L3_LCC_0905.tif
# Processed L3_AETI_0906.tif and L3_LCC_0906.tif
# Processed L3_AETI_0907.tif and L3_LCC_0907.tif
# Processed L3_AETI_0908.tif and L3_LCC_0908.tif
# Processed L3_AETI_0909.tif and L3_LCC_0909.tif
# Processed L3_AETI_0910.tif and L3_LCC_0910.tif
# Processed L3_AETI_0911.tif and L3_LCC_0911.tif
# Processed L3_AETI_0912.tif and L3_LCC_0912.tif
# Processed L3_AETI_0913.tif and L3_LCC_0913.tif
# Processed L3_AETI_0914.tif and L3_LCC_0914.tif
# Processed L3_AETI_0915.tif and L3_LCC_0915.tif
# Processed L3_AETI_0916.tif and L3_LCC_0916.tif
# Processed L3_AETI_0917.tif and L3_LCC_0917.tif
# Processed L3_AETI_0918.tif and L3_LCC_0918.tif
# Processed L3_AETI_0919.tif and L3_LCC_0919.tif
# Processed L3_AETI_0920.tif and L3_LCC_0920.tif
# Processed L3_AETI_0921.tif and L3_LCC_0921.tif
# Processed L3_AETI_0922.tif and L3_LCC_0922.tif
# Processed L3_AETI_0923.tif and L3_LCC_0923.tif
# Processed L3_AETI_0924.tif and L3_LCC_0924.tif
# Processed L3_AETI_0925.tif and L3_LCC_0925.tif
# Processed L3_AETI_0926.tif and L3_LCC_0926.tif
# Processed L3_AETI_0927.tif and L3_LCC_0927.tif
# Processed L3_AETI_0928.tif and L3_LCC_0928.tif
# Processed L3_AETI_0929.tif and L3_LCC_0929.tif
# Processed L3_AETI_0930.tif and L3_LCC_0930.tif
# Processed L3_AETI_0931.tif and L3_LCC_0931.tif
# Processed L3_AETI_0932.tif and L3_LCC_0932.tif
# Processed L3_AETI_0933.tif and L3_LCC_0933.tif
# Processed L3_AETI_0934.tif and L3_LCC_0934.tif
# Processed L3_AETI_0935.tif and L3_LCC_0935.tif
# Processed L3_AETI_0936.tif and L3_LCC_0936.tif
# Processed L3_AETI_1001.tif and L3_LCC_1001.tif
# Processed L3_AETI_1002.tif and L3_LCC_1002.tif
# Processed L3_AETI_1003.tif and L3_LCC_1003.tif
# Processed L3_AETI_1004.tif and L3_LCC_1004.tif
# Processed L3_AETI_1005.tif and L3_LCC_1005.tif
# Processed L3_AETI_1006.tif and L3_LCC_1006.tif
# Processed L3_AETI_1007.tif and L3_LCC_1007.tif
# Processed L3_AETI_1008.tif and L3_LCC_1008.tif
# Processed L3_AETI_1009.tif and L3_LCC_1009.tif
# Processed L3_AETI_1010.tif and L3_LCC_1010.tif
# Processed L3_AETI_1011.tif and L3_LCC_1011.tif
# Processed L3_AETI_1012.tif and L3_LCC_1012.tif
# Processed L3_AETI_1013.tif and L3_LCC_1013.tif
# Processed L3_AETI_1014.tif and L3_LCC_1014.tif
# Processed L3_AETI_1015.tif and L3_LCC_1015.tif
# Processed L3_AETI_1016.tif and L3_LCC_1016.tif
# Processed L3_AETI_1017.tif and L3_LCC_1017.tif
# Processed L3_AETI_1018.tif and L3_LCC_1018.tif
# Processed L3_AETI_1019.tif and L3_LCC_1019.tif
# Processed L3_AETI_1020.tif and L3_LCC_1020.tif
# Processed L3_AETI_1021.tif and L3_LCC_1021.tif
# Processed L3_AETI_1022.tif and L3_LCC_1022.tif
# Processed L3_AETI_1023.tif and L3_LCC_1023.tif
# Processed L3_AETI_1024.tif and L3_LCC_1024.tif
# Processed L3_AETI_1025.tif and L3_LCC_1025.tif
# Processed L3_AETI_1026.tif and L3_LCC_1026.tif
# Processed L3_AETI_1027.tif and L3_LCC_1027.tif
# Processed L3_AETI_1028.tif and L3_LCC_1028.tif
# Processed L3_AETI_1029.tif and L3_LCC_1029.tif
# Processed L3_AETI_1030.tif and L3_LCC_1030.tif
# Processed L3_AETI_1031.tif and L3_LCC_1031.tif
# Processed L3_AETI_1032.tif and L3_LCC_1032.tif
# Processed L3_AETI_1033.tif and L3_LCC_1033.tif
# Processed L3_AETI_1034.tif and L3_LCC_1034.tif
# Processed L3_AETI_1035.tif and L3_LCC_1035.tif
# Processed L3_AETI_1036.tif and L3_LCC_1036.tif
# Processed L3_AETI_1101.tif and L3_LCC_1101.tif
# Processed L3_AETI_1102.tif and L3_LCC_1102.tif
# Processed L3_AETI_1103.tif and L3_LCC_1103.tif
# Processed L3_AETI_1104.tif and L3_LCC_1104.tif
# Processed L3_AETI_1105.tif and L3_LCC_1105.tif
# Processed L3_AETI_1106.tif and L3_LCC_1106.tif
# Processed L3_AETI_1107.tif and L3_LCC_1107.tif
# Processed L3_AETI_1108.tif and L3_LCC_1108.tif
# Processed L3_AETI_1109.tif and L3_LCC_1109.tif
# Processed L3_AETI_1110.tif and L3_LCC_1110.tif
# Processed L3_AETI_1111.tif and L3_LCC_1111.tif
# Processed L3_AETI_1112.tif and L3_LCC_1112.tif
# Processed L3_AETI_1113.tif and L3_LCC_1113.tif
# Processed L3_AETI_1114.tif and L3_LCC_1114.tif
# Processed L3_AETI_1115.tif and L3_LCC_1115.tif
# Processed L3_AETI_1116.tif and L3_LCC_1116.tif
# Processed L3_AETI_1117.tif and L3_LCC_1117.tif
# Processed L3_AETI_1118.tif and L3_LCC_1118.tif
# Processed L3_AETI_1119.tif and L3_LCC_1119.tif
# Processed L3_AETI_1120.tif and L3_LCC_1120.tif
# Processed L3_AETI_1121.tif and L3_LCC_1121.tif
# Processed L3_AETI_1122.tif and L3_LCC_1122.tif
# Processed L3_AETI_1123.tif and L3_LCC_1123.tif
# Processed L3_AETI_1124.tif and L3_LCC_1124.tif
# Processed L3_AETI_1125.tif and L3_LCC_1125.tif
# Processed L3_AETI_1126.tif and L3_LCC_1126.tif
# Processed L3_AETI_1127.tif and L3_LCC_1127.tif
# Processed L3_AETI_1128.tif and L3_LCC_1128.tif
# Processed L3_AETI_1129.tif and L3_LCC_1129.tif
# Processed L3_AETI_1130.tif and L3_LCC_1130.tif
# Processed L3_AETI_1131.tif and L3_LCC_1131.tif
# Processed L3_AETI_1132.tif and L3_LCC_1132.tif
# Processed L3_AETI_1133.tif and L3_LCC_1133.tif
# Processed L3_AETI_1134.tif and L3_LCC_1134.tif
# Processed L3_AETI_1135.tif and L3_LCC_1135.tif
# Processed L3_AETI_1136.tif and L3_LCC_1136.tif
# Processed L3_AETI_1201.tif and L3_LCC_1201.tif
# Processed L3_AETI_1202.tif and L3_LCC_1202.tif
# Processed L3_AETI_1203.tif and L3_LCC_1203.tif
# Processed L3_AETI_1204.tif and L3_LCC_1204.tif
# Processed L3_AETI_1205.tif and L3_LCC_1205.tif
# Processed L3_AETI_1206.tif and L3_LCC_1206.tif
# Processed L3_AETI_1207.tif and L3_LCC_1207.tif
# Processed L3_AETI_1208.tif and L3_LCC_1208.tif
# Processed L3_AETI_1209.tif and L3_LCC_1209.tif
# Processed L3_AETI_1210.tif and L3_LCC_1210.tif
# Processed L3_AETI_1211.tif and L3_LCC_1211.tif
# Processed L3_AETI_1212.tif and L3_LCC_1212.tif
# Processed L3_AETI_1213.tif and L3_LCC_1213.tif
# Processed L3_AETI_1214.tif and L3_LCC_1214.tif
# Processed L3_AETI_1215.tif and L3_LCC_1215.tif
# Processed L3_AETI_1216.tif and L3_LCC_1216.tif
# Processed L3_AETI_1217.tif and L3_LCC_1217.tif
# Processed L3_AETI_1218.tif and L3_LCC_1218.tif
# Processed L3_AETI_1219.tif and L3_LCC_1219.tif
# Processed L3_AETI_1220.tif and L3_LCC_1220.tif
# Processed L3_AETI_1221.tif and L3_LCC_1221.tif
# Processed L3_AETI_1222.tif and L3_LCC_1222.tif
# Processed L3_AETI_1223.tif and L3_LCC_1223.tif
# Processed L3_AETI_1224.tif and L3_LCC_1224.tif
# Processed L3_AETI_1225.tif and L3_LCC_1225.tif
# Processed L3_AETI_1226.tif and L3_LCC_1226.tif
# Processed L3_AETI_1227.tif and L3_LCC_1227.tif
# Processed L3_AETI_1228.tif and L3_LCC_1228.tif
# Processed L3_AETI_1229.tif and L3_LCC_1229.tif
# Processed L3_AETI_1230.tif and L3_LCC_1230.tif
# Processed L3_AETI_1231.tif and L3_LCC_1231.tif
# Processed L3_AETI_1232.tif and L3_LCC_1232.tif
# Processed L3_AETI_1233.tif and L3_LCC_1233.tif
# Processed L3_AETI_1234.tif and L3_LCC_1234.tif
# Processed L3_AETI_1235.tif and L3_LCC_1235.tif
# Processed L3_AETI_1236.tif and L3_LCC_1236.tif
# Processed L3_AETI_1301.tif and L3_LCC_1301.tif
# Processed L3_AETI_1302.tif and L3_LCC_1302.tif
# Processed L3_AETI_1303.tif and L3_LCC_1303.tif
# Processed L3_AETI_1304.tif and L3_LCC_1304.tif
# Processed L3_AETI_1305.tif and L3_LCC_1305.tif
# Processed L3_AETI_1306.tif and L3_LCC_1306.tif
# Processed L3_AETI_1307.tif and L3_LCC_1307.tif
# Processed L3_AETI_1308.tif and L3_LCC_1308.tif
# Processed L3_AETI_1309.tif and L3_LCC_1309.tif
# Processed L3_AETI_1310.tif and L3_LCC_1310.tif
# Processed L3_AETI_1311.tif and L3_LCC_1311.tif
# Processed L3_AETI_1312.tif and L3_LCC_1312.tif
# Processed L3_AETI_1313.tif and L3_LCC_1313.tif
# Processed L3_AETI_1314.tif and L3_LCC_1314.tif
# Processed L3_AETI_1315.tif and L3_LCC_1315.tif
# Processed L3_AETI_1316.tif and L3_LCC_1316.tif
# Processed L3_AETI_1317.tif and L3_LCC_1317.tif
# Processed L3_AETI_1318.tif and L3_LCC_1318.tif
# Processed L3_AETI_1319.tif and L3_LCC_1319.tif
# Processed L3_AETI_1320.tif and L3_LCC_1320.tif
# Processed L3_AETI_1321.tif and L3_LCC_1321.tif
# Processed L3_AETI_1322.tif and L3_LCC_1322.tif
# Processed L3_AETI_1323.tif and L3_LCC_1323.tif
# Processed L3_AETI_1324.tif and L3_LCC_1324.tif
# Processed L3_AETI_1325.tif and L3_LCC_1325.tif
# Processed L3_AETI_1326.tif and L3_LCC_1326.tif
# Processed L3_AETI_1327.tif and L3_LCC_1327.tif
# Processed L3_AETI_1328.tif and L3_LCC_1328.tif
# Processed L3_AETI_1329.tif and L3_LCC_1329.tif
# Processed L3_AETI_1330.tif and L3_LCC_1330.tif
# Processed L3_AETI_1331.tif and L3_LCC_1331.tif
# Processed L3_AETI_1332.tif and L3_LCC_1332.tif
# Processed L3_AETI_1333.tif and L3_LCC_1333.tif
# Processed L3_AETI_1334.tif and L3_LCC_1334.tif
# Processed L3_AETI_1335.tif and L3_LCC_1335.tif
# Processed L3_AETI_1336.tif and L3_LCC_1336.tif
# Processed L3_AETI_1401.tif and L3_LCC_1401.tif
# Processed L3_AETI_1402.tif and L3_LCC_1402.tif
# Processed L3_AETI_1403.tif and L3_LCC_1403.tif
# Processed L3_AETI_1404.tif and L3_LCC_1404.tif
# Processed L3_AETI_1405.tif and L3_LCC_1405.tif
# Processed L3_AETI_1406.tif and L3_LCC_1406.tif
# Processed L3_AETI_1407.tif and L3_LCC_1407.tif
# Processed L3_AETI_1408.tif and L3_LCC_1408.tif
# Processed L3_AETI_1409.tif and L3_LCC_1409.tif
# Processed L3_AETI_1410.tif and L3_LCC_1410.tif
# Processed L3_AETI_1411.tif and L3_LCC_1411.tif
# Processed L3_AETI_1412.tif and L3_LCC_1412.tif
# Processed L3_AETI_1413.tif and L3_LCC_1413.tif
# Processed L3_AETI_1414.tif and L3_LCC_1414.tif
# Processed L3_AETI_1415.tif and L3_LCC_1415.tif
# Processed L3_AETI_1416.tif and L3_LCC_1416.tif
# Processed L3_AETI_1417.tif and L3_LCC_1417.tif
# Processed L3_AETI_1418.tif and L3_LCC_1418.tif
# Processed L3_AETI_1419.tif and L3_LCC_1419.tif
# Processed L3_AETI_1420.tif and L3_LCC_1420.tif
# Processed L3_AETI_1421.tif and L3_LCC_1421.tif
# Processed L3_AETI_1422.tif and L3_LCC_1422.tif
# Processed L3_AETI_1423.tif and L3_LCC_1423.tif
# Processed L3_AETI_1424.tif and L3_LCC_1424.tif
# Processed L3_AETI_1425.tif and L3_LCC_1425.tif
# Processed L3_AETI_1426.tif and L3_LCC_1426.tif
# Processed L3_AETI_1427.tif and L3_LCC_1427.tif
# Processed L3_AETI_1428.tif and L3_LCC_1428.tif
# Processed L3_AETI_1429.tif and L3_LCC_1429.tif
# Processed L3_AETI_1430.tif and L3_LCC_1430.tif
# Processed L3_AETI_1431.tif and L3_LCC_1431.tif
# Processed L3_AETI_1432.tif and L3_LCC_1432.tif
# Processed L3_AETI_1433.tif and L3_LCC_1433.tif
# Processed L3_AETI_1434.tif and L3_LCC_1434.tif
# Processed L3_AETI_1435.tif and L3_LCC_1435.tif
# Processed L3_AETI_1436.tif and L3_LCC_1436.tif
# Processed L3_AETI_1501.tif and L3_LCC_1501.tif
# Processed L3_AETI_1502.tif and L3_LCC_1502.tif
# Processed L3_AETI_1503.tif and L3_LCC_1503.tif
# Processed L3_AETI_1504.tif and L3_LCC_1504.tif
# Processed L3_AETI_1505.tif and L3_LCC_1505.tif
# Processed L3_AETI_1506.tif and L3_LCC_1506.tif
# Processed L3_AETI_1507.tif and L3_LCC_1507.tif
# Processed L3_AETI_1508.tif and L3_LCC_1508.tif
# Processed L3_AETI_1509.tif and L3_LCC_1509.tif
# Processed L3_AETI_1510.tif and L3_LCC_1510.tif
# Processed L3_AETI_1511.tif and L3_LCC_1511.tif
# Processed L3_AETI_1512.tif and L3_LCC_1512.tif
# Processed L3_AETI_1513.tif and L3_LCC_1513.tif
# Processed L3_AETI_1514.tif and L3_LCC_1514.tif
# Processed L3_AETI_1515.tif and L3_LCC_1515.tif
# Processed L3_AETI_1516.tif and L3_LCC_1516.tif
# Processed L3_AETI_1517.tif and L3_LCC_1517.tif
# Processed L3_AETI_1518.tif and L3_LCC_1518.tif
# Processed L3_AETI_1519.tif and L3_LCC_1519.tif
# Processed L3_AETI_1520.tif and L3_LCC_1520.tif
# Processed L3_AETI_1521.tif and L3_LCC_1521.tif
# Processed L3_AETI_1522.tif and L3_LCC_1522.tif
# Processed L3_AETI_1523.tif and L3_LCC_1523.tif
# Processed L3_AETI_1524.tif and L3_LCC_1524.tif
# Processed L3_AETI_1525.tif and L3_LCC_1525.tif
# Processed L3_AETI_1526.tif and L3_LCC_1526.tif
# Processed L3_AETI_1527.tif and L3_LCC_1527.tif
# Processed L3_AETI_1528.tif and L3_LCC_1528.tif
# Processed L3_AETI_1529.tif and L3_LCC_1529.tif
# Processed L3_AETI_1530.tif and L3_LCC_1530.tif
# Processed L3_AETI_1531.tif and L3_LCC_1531.tif
# Processed L3_AETI_1532.tif and L3_LCC_1532.tif
# Processed L3_AETI_1533.tif and L3_LCC_1533.tif
# Processed L3_AETI_1534.tif and L3_LCC_1534.tif
# Processed L3_AETI_1535.tif and L3_LCC_1535.tif
# Processed L3_AETI_1536.tif and L3_LCC_1536.tif
# Processed L3_AETI_1601.tif and L3_LCC_1601.tif
# Processed L3_AETI_1602.tif and L3_LCC_1602.tif
# Processed L3_AETI_1603.tif and L3_LCC_1603.tif
# Processed L3_AETI_1604.tif and L3_LCC_1604.tif
# Processed L3_AETI_1605.tif and L3_LCC_1605.tif
# Processed L3_AETI_1606.tif and L3_LCC_1606.tif
# Processed L3_AETI_1607.tif and L3_LCC_1607.tif
# Processed L3_AETI_1608.tif and L3_LCC_1608.tif
# Processed L3_AETI_1609.tif and L3_LCC_1609.tif
# Processed L3_AETI_1610.tif and L3_LCC_1610.tif
# Processed L3_AETI_1611.tif and L3_LCC_1611.tif
# Processed L3_AETI_1612.tif and L3_LCC_1612.tif
# Processed L3_AETI_1613.tif and L3_LCC_1613.tif
# Processed L3_AETI_1614.tif and L3_LCC_1614.tif
# Processed L3_AETI_1615.tif and L3_LCC_1615.tif
# Processed L3_AETI_1616.tif and L3_LCC_1616.tif
# Processed L3_AETI_1617.tif and L3_LCC_1617.tif
# Processed L3_AETI_1618.tif and L3_LCC_1618.tif
# Processed L3_AETI_1619.tif and L3_LCC_1619.tif
# Processed L3_AETI_1620.tif and L3_LCC_1620.tif
# Processed L3_AETI_1621.tif and L3_LCC_1621.tif
# Processed L3_AETI_1622.tif and L3_LCC_1622.tif
# Processed L3_AETI_1623.tif and L3_LCC_1623.tif
# Processed L3_AETI_1624.tif and L3_LCC_1624.tif
# Processed L3_AETI_1625.tif and L3_LCC_1625.tif
# Processed L3_AETI_1626.tif and L3_LCC_1626.tif
# Processed L3_AETI_1627.tif and L3_LCC_1627.tif
# Processed L3_AETI_1628.tif and L3_LCC_1628.tif
# Processed L3_AETI_1629.tif and L3_LCC_1629.tif
# Processed L3_AETI_1630.tif and L3_LCC_1630.tif
# Processed L3_AETI_1631.tif and L3_LCC_1631.tif
# Processed L3_AETI_1632.tif and L3_LCC_1632.tif
# Processed L3_AETI_1633.tif and L3_LCC_1633.tif
# Processed L3_AETI_1634.tif and L3_LCC_1634.tif
# Processed L3_AETI_1635.tif and L3_LCC_1635.tif
# Processed L3_AETI_1636.tif and L3_LCC_1636.tif
# Processed L3_AETI_1701.tif and L3_LCC_1701.tif
# Processed L3_AETI_1702.tif and L3_LCC_1702.tif
# Processed L3_AETI_1703.tif and L3_LCC_1703.tif
# Processed L3_AETI_1704.tif and L3_LCC_1704.tif
# Processed L3_AETI_1705.tif and L3_LCC_1705.tif
# Processed L3_AETI_1706.tif and L3_LCC_1706.tif
# Processed L3_AETI_1707.tif and L3_LCC_1707.tif
# Processed L3_AETI_1708.tif and L3_LCC_1708.tif
# Processed L3_AETI_1709.tif and L3_LCC_1709.tif
# Processed L3_AETI_1710.tif and L3_LCC_1710.tif
# Processed L3_AETI_1711.tif and L3_LCC_1711.tif
# Processed L3_AETI_1712.tif and L3_LCC_1712.tif
# Processed L3_AETI_1713.tif and L3_LCC_1713.tif
# Processed L3_AETI_1714.tif and L3_LCC_1714.tif
# Processed L3_AETI_1715.tif and L3_LCC_1715.tif
# Processed L3_AETI_1716.tif and L3_LCC_1716.tif
# Processed L3_AETI_1717.tif and L3_LCC_1717.tif
# Processed L3_AETI_1718.tif and L3_LCC_1718.tif
# Processed L3_AETI_1719.tif and L3_LCC_1719.tif
# Processed L3_AETI_1720.tif and L3_LCC_1720.tif
# Processed L3_AETI_1721.tif and L3_LCC_1721.tif
# Processed L3_AETI_1722.tif and L3_LCC_1722.tif
# Processed L3_AETI_1723.tif and L3_LCC_1723.tif
# Processed L3_AETI_1724.tif and L3_LCC_1724.tif
# Processed L3_AETI_1725.tif and L3_LCC_1725.tif
# Processed L3_AETI_1726.tif and L3_LCC_1726.tif
# Processed L3_AETI_1727.tif and L3_LCC_1727.tif
# Processed L3_AETI_1728.tif and L3_LCC_1728.tif
# Processed L3_AETI_1729.tif and L3_LCC_1729.tif
# Processed L3_AETI_1730.tif and L3_LCC_1730.tif
# Processed L3_AETI_1731.tif and L3_LCC_1731.tif
# Processed L3_AETI_1732.tif and L3_LCC_1732.tif
# Processed L3_AETI_1733.tif and L3_LCC_1733.tif
# Processed L3_AETI_1734.tif and L3_LCC_1734.tif
# Processed L3_AETI_1735.tif and L3_LCC_1735.tif
# Processed L3_AETI_1736.tif and L3_LCC_1736.tif
# Processed L3_AETI_1801.tif and L3_LCC_1801.tif
# Processed L3_AETI_1802.tif and L3_LCC_1802.tif
# Processed L3_AETI_1803.tif and L3_LCC_1803.tif
# Processed L3_AETI_1804.tif and L3_LCC_1804.tif
# Processed L3_AETI_1805.tif and L3_LCC_1805.tif
# Processed L3_AETI_1806.tif and L3_LCC_1806.tif
# Processed L3_AETI_1807.tif and L3_LCC_1807.tif
# Processed L3_AETI_1808.tif and L3_LCC_1808.tif
# Processed L3_AETI_1809.tif and L3_LCC_1809.tif
# Processed L3_AETI_1810.tif and L3_LCC_1810.tif
# Processed L3_AETI_1811.tif and L3_LCC_1811.tif
# Processed L3_AETI_1812.tif and L3_LCC_1812.tif
# Processed L3_AETI_1813.tif and L3_LCC_1813.tif
# Processed L3_AETI_1814.tif and L3_LCC_1814.tif
# Processed L3_AETI_1815.tif and L3_LCC_1815.tif
# Processed L3_AETI_1816.tif and L3_LCC_1816.tif
# Processed L3_AETI_1817.tif and L3_LCC_1817.tif
# Processed L3_AETI_1818.tif and L3_LCC_1818.tif
# Processed L3_AETI_1819.tif and L3_LCC_1819.tif
# Processed L3_AETI_1820.tif and L3_LCC_1820.tif
# Processed L3_AETI_1821.tif and L3_LCC_1821.tif
# Processed L3_AETI_1822.tif and L3_LCC_1822.tif
# Processed L3_AETI_1823.tif and L3_LCC_1823.tif
# Processed L3_AETI_1824.tif and L3_LCC_1824.tif
# Processed L3_AETI_1825.tif and L3_LCC_1825.tif
# Processed L3_AETI_1826.tif and L3_LCC_1826.tif
# Processed L3_AETI_1827.tif and L3_LCC_1827.tif
# Processed L3_AETI_1828.tif and L3_LCC_1828.tif
# Processed L3_AETI_1829.tif and L3_LCC_1829.tif
# Processed L3_AETI_1830.tif and L3_LCC_1830.tif
# Processed L3_AETI_1831.tif and L3_LCC_1831.tif
# Processed L3_AETI_1832.tif and L3_LCC_1832.tif
# Processed L3_AETI_1833.tif and L3_LCC_1833.tif
# Processed L3_AETI_1834.tif and L3_LCC_1834.tif
# Processed L3_AETI_1835.tif and L3_LCC_1835.tif
# Processed L3_AETI_1836.tif and L3_LCC_1836.tif
# Processed L3_AETI_1901.tif and L3_LCC_1901.tif
# Processed L3_AETI_1902.tif and L3_LCC_1902.tif
# Processed L3_AETI_1903.tif and L3_LCC_1903.tif
# Processed L3_AETI_1904.tif and L3_LCC_1904.tif
# Processed L3_AETI_1905.tif and L3_LCC_1905.tif
# Processed L3_AETI_1906.tif and L3_LCC_1906.tif
# Processed L3_AETI_1907.tif and L3_LCC_1907.tif
# Processed L3_AETI_1908.tif and L3_LCC_1908.tif
# Processed L3_AETI_1909.tif and L3_LCC_1909.tif
# Processed L3_AETI_1910.tif and L3_LCC_1910.tif
# Processed L3_AETI_1911.tif and L3_LCC_1911.tif
# Processed L3_AETI_1912.tif and L3_LCC_1912.tif
# Processed L3_AETI_1913.tif and L3_LCC_1913.tif
# Processed L3_AETI_1914.tif and L3_LCC_1914.tif
# Processed L3_AETI_1915.tif and L3_LCC_1915.tif
# Processed L3_AETI_1916.tif and L3_LCC_1916.tif
# Processed L3_AETI_1917.tif and L3_LCC_1917.tif
# Processed L3_AETI_1918.tif and L3_LCC_1918.tif
# Processed L3_AETI_1919.tif and L3_LCC_1919.tif
# Processed L3_AETI_1920.tif and L3_LCC_1920.tif
# Processed L3_AETI_1921.tif and L3_LCC_1921.tif
# Processed L3_AETI_1922.tif and L3_LCC_1922.tif
# Processed L3_AETI_1923.tif and L3_LCC_1923.tif
# Processed L3_AETI_1924.tif and L3_LCC_1924.tif
# Processed L3_AETI_1925.tif and L3_LCC_1925.tif
# Processed L3_AETI_1926.tif and L3_LCC_1926.tif
# Processed L3_AETI_1927.tif and L3_LCC_1927.tif
# Processed L3_AETI_1928.tif and L3_LCC_1928.tif
# Processed L3_AETI_1929.tif and L3_LCC_1929.tif
# Processed L3_AETI_1930.tif and L3_LCC_1930.tif
# Processed L3_AETI_1931.tif and L3_LCC_1931.tif
# Processed L3_AETI_1932.tif and L3_LCC_1932.tif
# Processed L3_AETI_1933.tif and L3_LCC_1933.tif
# Processed L3_AETI_1934.tif and L3_LCC_1934.tif
# Processed L3_AETI_1935.tif and L3_LCC_1935.tif
# Processed L3_AETI_1936.tif and L3_LCC_1936.tif
# Processed L3_AETI_2001.tif and L3_LCC_2001.tif
# Processed L3_AETI_2002.tif and L3_LCC_2002.tif
# Processed L3_AETI_2003.tif and L3_LCC_2003.tif
# Processed L3_AETI_2004.tif and L3_LCC_2004.tif
# Processed L3_AETI_2005.tif and L3_LCC_2005.tif
# Processed L3_AETI_2006.tif and L3_LCC_2006.tif
# Processed L3_AETI_2007.tif and L3_LCC_2007.tif
# Processed L3_AETI_2008.tif and L3_LCC_2008.tif
# Processed L3_AETI_2009.tif and L3_LCC_2009.tif
# Processed L3_AETI_2010.tif and L3_LCC_2010.tif
# Processed L3_AETI_2011.tif and L3_LCC_2011.tif
# Processed L3_AETI_2012.tif and L3_LCC_2012.tif
# Processed L3_AETI_2013.tif and L3_LCC_2013.tif
# Processed L3_AETI_2014.tif and L3_LCC_2014.tif
# Processed L3_AETI_2015.tif and L3_LCC_2015.tif
# Processed L3_AETI_2016.tif and L3_LCC_2016.tif
# Processed L3_AETI_2017.tif and L3_LCC_2017.tif
# Processed L3_AETI_2018.tif and L3_LCC_2018.tif
# Processed L3_AETI_2019.tif and L3_LCC_2019.tif
# Processed L3_AETI_2020.tif and L3_LCC_2020.tif
# Processed L3_AETI_2021.tif and L3_LCC_2021.tif
# Processed L3_AETI_2022.tif and L3_LCC_2022.tif
# Processed L3_AETI_2023.tif and L3_LCC_2023.tif
# Processed L3_AETI_2024.tif and L3_LCC_2024.tif
# Processed L3_AETI_2025.tif and L3_LCC_2025.tif
# Processed L3_AETI_2026.tif and L3_LCC_2026.tif
# Processed L3_AETI_2027.tif and L3_LCC_2027.tif
# Processed L3_AETI_2028.tif and L3_LCC_2028.tif
# Processed L3_AETI_2029.tif and L3_LCC_2029.tif
# Processed L3_AETI_2030.tif and L3_LCC_2030.tif
# Processed L3_AETI_2031.tif and L3_LCC_2031.tif
# Processed L3_AETI_2032.tif and L3_LCC_2032.tif
# Processed L3_AETI_2033.tif and L3_LCC_2033.tif
# Processed L3_AETI_2034.tif and L3_LCC_2034.tif
# Processed L3_AETI_2035.tif and L3_LCC_2035.tif
# Processed L3_AETI_2036.tif and L3_LCC_2036.tif
# Processed L3_AETI_2101.tif and L3_LCC_2101.tif
# Processed L3_AETI_2102.tif and L3_LCC_2102.tif
# Processed L3_AETI_2103.tif and L3_LCC_2103.tif
# Processed L3_AETI_2104.tif and L3_LCC_2104.tif
# Processed L3_AETI_2105.tif and L3_LCC_2105.tif
# Processed L3_AETI_2106.tif and L3_LCC_2106.tif
# Processed L3_AETI_2107.tif and L3_LCC_2107.tif
# Processed L3_AETI_2108.tif and L3_LCC_2108.tif
# Processed L3_AETI_2109.tif and L3_LCC_2109.tif
# Processed L3_AETI_2110.tif and L3_LCC_2110.tif
# Processed L3_AETI_2111.tif and L3_LCC_2111.tif
# Processed L3_AETI_2112.tif and L3_LCC_2112.tif
# Processed L3_AETI_2113.tif and L3_LCC_2113.tif
# Processed L3_AETI_2114.tif and L3_LCC_2114.tif
# Processed L3_AETI_2115.tif and L3_LCC_2115.tif
# Processed L3_AETI_2116.tif and L3_LCC_2116.tif
# Processed L3_AETI_2117.tif and L3_LCC_2117.tif
# Processed L3_AETI_2118.tif and L3_LCC_2118.tif
# Processed L3_AETI_2119.tif and L3_LCC_2119.tif
# Processed L3_AETI_2120.tif and L3_LCC_2120.tif
# Processed L3_AETI_2121.tif and L3_LCC_2121.tif
# Processed L3_AETI_2122.tif and L3_LCC_2122.tif
# Processed L3_AETI_2123.tif and L3_LCC_2123.tif
# Processed L3_AETI_2124.tif and L3_LCC_2124.tif
# Processed L3_AETI_2125.tif and L3_LCC_2125.tif
# Processed L3_AETI_2126.tif and L3_LCC_2126.tif
# Processed L3_AETI_2127.tif and L3_LCC_2127.tif
# Processed L3_AETI_2128.tif and L3_LCC_2128.tif
# Processed L3_AETI_2129.tif and L3_LCC_2129.tif
# Processed L3_AETI_2130.tif and L3_LCC_2130.tif
# Processed L3_AETI_2131.tif and L3_LCC_2131.tif
# Processed L3_AETI_2132.tif and L3_LCC_2132.tif
# Processed L3_AETI_2133.tif and L3_LCC_2133.tif
# Processed L3_AETI_2134.tif and L3_LCC_2134.tif
# Processed L3_AETI_2135.tif and L3_LCC_2135.tif
# Processed L3_AETI_2136.tif and L3_LCC_2136.tif
# Processed L3_AETI_2201.tif and L3_LCC_2201.tif
# Processed L3_AETI_2202.tif and L3_LCC_2202.tif
# Processed L3_AETI_2203.tif and L3_LCC_2203.tif
# Processed L3_AETI_2204.tif and L3_LCC_2204.tif
# Processed L3_AETI_2205.tif and L3_LCC_2205.tif
# Processed L3_AETI_2206.tif and L3_LCC_2206.tif
# Processed L3_AETI_2207.tif and L3_LCC_2207.tif
# Processed L3_AETI_2208.tif and L3_LCC_2208.tif
# Processed L3_AETI_2209.tif and L3_LCC_2209.tif
# Processed L3_AETI_2210.tif and L3_LCC_2210.tif
# Processed L3_AETI_2211.tif and L3_LCC_2211.tif
# Processed L3_AETI_2212.tif and L3_LCC_2212.tif
# Processed L3_AETI_2213.tif and L3_LCC_2213.tif
# Processed L3_AETI_2214.tif and L3_LCC_2214.tif
# Processed L3_AETI_2215.tif and L3_LCC_2215.tif
# Processed L3_AETI_2216.tif and L3_LCC_2216.tif
# Processed L3_AETI_2217.tif and L3_LCC_2217.tif
# Processed L3_AETI_2218.tif and L3_LCC_2218.tif
# Processed L3_AETI_2219.tif and L3_LCC_2219.tif
# Processed L3_AETI_2220.tif and L3_LCC_2220.tif
# Processed L3_AETI_2221.tif and L3_LCC_2221.tif
# Processed L3_AETI_2222.tif and L3_LCC_2222.tif
# Processed L3_AETI_2223.tif and L3_LCC_2223.tif
# Processed L3_AETI_2224.tif and L3_LCC_2224.tif
# Processed L3_AETI_2225.tif and L3_LCC_2225.tif
# Processed L3_AETI_2226.tif and L3_LCC_2226.tif
# Processed L3_AETI_2227.tif and L3_LCC_2227.tif
# Processed L3_AETI_2228.tif and L3_LCC_2228.tif
# Processed L3_AETI_2229.tif and L3_LCC_2229.tif
# Processed L3_AETI_2230.tif and L3_LCC_2230.tif
# Processed L3_AETI_2231.tif and L3_LCC_2231.tif
# Processed L3_AETI_2232.tif and L3_LCC_2232.tif
# Processed L3_AETI_2233.tif and L3_LCC_2233.tif
# Processed L3_AETI_2234.tif and L3_LCC_2234.tif
# Processed L3_AETI_2235.tif and L3_LCC_2235.tif
# Processed L3_AETI_2236.tif and L3_LCC_2236.tif
# Results saved to average_aeti_all_crops.csv

# %%
import os
import numpy as np
import pandas as pd
import tifffile as tiff  # Use tifffile instead of Pillow for reading TIFF images

# Define the class values for all crops (normal and irrigated variants)
crop_classes = {
    "Potato": [10, 110],
    "Orchard (dense)": [13, 113],
    "Grapes": [15, 115],
    "Wheat": [108],
    "Maize": [109],
    "Potatoes": [110],
    "Grapes (Irrigated)": [115],
    "Rice": [120],
    "Cotton": [124],
    "Clover": [125],
    "Onions": [126],
    "Carrots": [127],
    "Eggplants": [128],
    "Flax": [129],
    "Sugar beet": [131]
}

# File selection based on user preference for each season
file_selection = {
    "Winter": "L3_AETI_2228.tif",  # File for Winter
    "Summer": "L3_AETI_2216.tif",  # File for Summer
    "Nili": "L3_AETI_2221.tif"     # File for Nili
}

# Directories containing the AETI and Land Classification files
aeti_dir = r'D:\Thesis Work\FAO_WAPOR_Data\waporact_test\L3\02_download\L3_AETI_D'
land_class_dir = r'D:\Thesis Work\FAO_WAPOR_Data\waporact_test\L3\02_download\L3_LCC_D'

# Initialize a list to store the results
results = []

# Extract the number after AETI and LCC in filenames for pairing
def extract_number(filename, prefix):
    start = filename.find(prefix) + len(prefix)
    end = filename.find('.tif', start)
    return filename[start:end]

# Create a dictionary for land class files with extracted numbers as keys
land_class_files = os.listdir(land_class_dir)
land_class_dict = {extract_number(f, 'LCC_'): f for f in land_class_files if f.endswith('.tif')}

# Function to process each pair of AETI and Land Classification files
def process_files(aeti_file, land_class_file):
    # Load the images using tifffile
    aeti_data = tiff.imread(aeti_file)
    land_class_data = tiff.imread(land_class_file)

    # Dictionary to store the pixel count for each crop
    crop_pixel_counts = {}

    # Check if both images have the same shape
    if aeti_data.shape != land_class_data.shape:
        print(f"Shape mismatch: AETI {aeti_data.shape}, Land Classification {land_class_data.shape}")
        return None  # Skip processing this pair
    
    # Iterate over all crops
    for crop_name, class_values in crop_classes.items():
        # Identify pixels corresponding to the crop in the land classification image
        crop_pixels = np.isin(land_class_data, class_values)
        
        # Count the number of pixels for this crop
        crop_pixel_count = np.sum(crop_pixels)
        crop_pixel_counts[crop_name] = crop_pixel_count
    
    return crop_pixel_counts

# Initialize a dictionary to store seasonal pixel counts for each crop
seasonal_crop_data = {season: {crop: 0 for crop in crop_classes} for season in file_selection}

# Iterate through the files selected for each season
for season, aeti_filename in file_selection.items():
    aeti_file_path = os.path.join(aeti_dir, aeti_filename)
    
    # Extract the number from the AETI filename
    number = extract_number(aeti_filename, 'AETI_')
    
    # Find the corresponding land class filename using the extracted number
    land_class_filename = land_class_dict.get(number)
    
    if land_class_filename:
        # Construct the full path for the land class file
        land_class_file_path = os.path.join(land_class_dir, land_class_filename)
        
        # Process the files and get the pixel counts for each crop
        crop_pixel_counts = process_files(aeti_file_path, land_class_file_path)
        
        # If no crop pixels were found, skip to the next file
        if crop_pixel_counts is None:
            continue
        
        # Add the pixel counts to the corresponding season's data
        for crop_name, pixel_count in crop_pixel_counts.items():
            seasonal_crop_data[season][crop_name] += pixel_count
        
        print(f"Processed {aeti_filename} and {land_class_filename} for {season} season")
    else:
        print(f"Matching land class file not found for {aeti_filename}")

# Check if any data was processed
if not any(any(v > 0 for v in crops.values()) for crops in seasonal_crop_data.values()):
    print("No valid data was processed.")
else:
    # Convert the seasonal crop data to percentages
    seasonal_results = []
    for season, crops_data in seasonal_crop_data.items():
        total_pixels = sum(crops_data.values())
        
        if total_pixels > 0:  # Avoid division by zero
            for crop_name, pixel_count in crops_data.items():
                crop_percentage = (pixel_count / total_pixels) * 100
                seasonal_results.append({
                    'Season': season,
                    'Crop': crop_name,
                    'Crop Percentage': crop_percentage
                })

    # Convert the results to a DataFrame
    seasonal_results_df = pd.DataFrame(seasonal_results)

    # Save the seasonal crop percentages to a CSV file
    seasonal_results_df.to_csv('seasonal_crop_percentages.csv', index=False)
    print("Seasonal crop percentages saved to seasonal_crop_percentages.csv")
# Out:
# Processed L3_AETI_2228.tif and L3_LCC_2228.tif for Winter season
# Processed L3_AETI_2216.tif and L3_LCC_2216.tif for Summer season
# Processed L3_AETI_2221.tif and L3_LCC_2221.tif for Nili season
# Seasonal crop percentages saved to seasonal_crop_percentages.csv
